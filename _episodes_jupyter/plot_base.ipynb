# %% [markdown]
# # Introduction to matplotlib

# %% [markdown]
# `matplotlib` is the most widely used scientific plotting library in Python.
# Commonly use a sub-library called matplotlib.pyplot.
# The Jupyter Notebook will render plots inline if we ask it to using a "magic" command.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# Create a simple plot

# %%
time = [0, 1, 2, 3]
position = [0, 100, 200, 300]

plt.plot(time, position)
plt.xlabel('Time (hr)')
plt.ylabel('Position (km)')
# Out:
# Text(0,0.5,'Position (km)')

# %% [markdown]
# # Plot data directly from a `Pandas dataframe`.

# %% [markdown]
# We can also plot Pandas dataframes.
# This implicitly uses `matplotlib.pyplot`.
# Before plotting, we convert the column headings from a `string` to `integer` data type, since they represent numerical values

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/mydatastory/r_intro_class/master/data/gapminder.csv')

df1 = df.loc[df['country'] == 'United States', :]  # used previously from data_structures lesson
df1
# Out:
#             country  year          pop continent  lifeExp    gdpPercap
# 1608  United States  1952  157553000.0  Americas   68.440  13990.48208
# 1609  United States  1957  171984000.0  Americas   69.490  14847.12712
# 1610  United States  1962  186538000.0  Americas   70.210  16173.14586
# 1611  United States  1967  198712000.0  Americas   70.760  19530.36557
# 1612  United States  1972  209896000.0  Americas   71.340  21806.03594
# 1613  United States  1977  220239000.0  Americas   73.380  24072.63213
# 1614  United States  1982  232187835.0  Americas   74.650  25009.55914
# 1615  United States  1987  242803533.0  Americas   75.020  29884.35041
# 1616  United States  1992  256894189.0  Americas   76.090  32003.93224
# 1617  United States  1997  272911760.0  Americas   76.810  35767.43303
# 1618  United States  2002  287675526.0  Americas   77.310  39097.09955
# 1619  United States  2007  301139947.0  Americas   78.242  42951.65309

# %%
df1.plot(x='year', y='lifeExp')

# %% [markdown]
# # Many styles of plot are available.

# %%
plt.style.use('ggplot')
df1.plot(x='year', y='lifeExp', kind='scatter')

# %%
plt.style.use('default')

# %%
df1 = df.loc[df['country'].isin(['United States', 'United Kingdom']), :]  # used previously from data_structures lesson
df1
# Out:
#              country  year          pop continent  lifeExp     gdpPercap
# 1596  United Kingdom  1952   50430000.0    Europe   69.180   9979.508487
# 1597  United Kingdom  1957   51430000.0    Europe   70.420  11283.177950
# 1598  United Kingdom  1962   53292000.0    Europe   70.760  12477.177070
# 1599  United Kingdom  1967   54959000.0    Europe   71.360  14142.850890
# 1600  United Kingdom  1972   56079000.0    Europe   72.010  15895.116410
# 1601  United Kingdom  1977   56179000.0    Europe   72.760  17428.748460
# 1602  United Kingdom  1982   56339704.0    Europe   74.040  18232.424520
# 1603  United Kingdom  1987   56981620.0    Europe   75.007  21664.787670
# 1604  United Kingdom  1992   57866349.0    Europe   76.420  22705.092540
# 1605  United Kingdom  1997   58808266.0    Europe   77.218  26074.531360
# 1606  United Kingdom  2002   59912431.0    Europe   78.471  29478.999190
# 1607  United Kingdom  2007   60776238.0    Europe   79.425  33203.261280
# ...

# %% [markdown]
# # Multi Line Plot

# %% [markdown]
# First we are going to turn the data we want into a pivot table for easy input into the `plot` function.

# %%
df1.pivot(index='year', columns='country', values='lifeExp')
# Out:
# country  United Kingdom  United States
# year
# 1952             69.180         68.440
# 1957             70.420         69.490
# 1962             70.760         70.210
# 1967             71.360         70.760
# 1972             72.010         71.340
# 1977             72.760         73.380
# 1982             74.040         74.650
# 1987             75.007         75.020
# 1992             76.420         76.090
# 1997             77.218         76.810
# 2002             78.471         77.310
# 2007             79.425         78.242

# %% [markdown]
# # Histogram

# %%
df_lifeExp = df.pivot(index='country', columns='year', values='lifeExp')
df_lifeExp.head()
# Out:
# year           1952    1957    1962    1967    1972    1977    1982    1987  \
# country
# Afghanistan  28.801  30.332  31.997  34.020  36.088  38.438  39.854  40.822
# Albania      55.230  59.280  64.820  66.220  67.690  68.930  70.420  72.000
# Algeria      43.077  45.685  48.303  51.407  54.518  58.014  61.368  65.799
# Angola       30.015  31.999  34.000  35.985  37.928  39.483  39.942  39.906
# Argentina    62.485  64.399  65.142  65.634  67.065  68.481  69.942  70.774
#
# year           1992    1997    2002    2007
# country
# Afghanistan  41.674  41.763  42.129  43.828
# Albania      71.581  72.950  75.651  76.423
# Algeria      67.744  69.152  70.994  72.301
# Angola       40.647  40.963  41.003  42.731
# Argentina    71.868  73.275  74.340  75.320

# %%
df_lifeExp[2007].plot.hist(title='Histogram of Life Expectancy in 2007 of all countries')

# %% [markdown]
# # Box Plots

# %%
color = dict(boxes='DarkGreen', whiskers='DarkOrange', medians='DarkBlue', caps='Gray')

df_lifeExp[[2002,2007]].plot.box(color=color)

# %%
df_lifeExp.plot.box(color=color)

# %% [markdown]
# Below we use the `sample` function to sample both the rows and columns.

# %%
df_lifeExp.sample(n=1, axis=1).sample(n=5).plot.bar()

# %% [markdown]
# # Stacked and grouped barplots

# %%
df_lifeExp.sample(n=5).sample(n=3, axis=1).plot.bar()

# %%
df_pop = df.pivot_table(index=['continent','country'], columns='year', values='pop')
df_pop.head()
# Out:
# year                         1952        1957        1962        1967  \
# continent country
# Africa    Algeria       9279525.0  10270856.0  11000948.0  12760499.0
#           Angola        4232095.0   4561361.0   4826015.0   5247469.0
#           Benin         1738315.0   1925173.0   2151895.0   2427334.0
#           Botswana       442308.0    474639.0    512764.0    553541.0
#           Burkina Faso  4469979.0   4713416.0   4919632.0   5127935.0
#
# year                          1972        1977        1982        1987  \
# continent country
# Africa    Algeria       14760787.0  17152804.0  20033753.0  23254956.0
#           Angola         5894858.0   6162675.0   7016384.0   7874230.0
#           Benin          2761407.0   3168267.0   3641603.0   4243788.0
#           Botswana        619351.0    781472.0    970347.0   1151184.0
#           Burkina Faso   5433886.0   5889574.0   6634596.0   7586551.0
#
# year                          1992        1997        2002        2007
# ...

# %%
df_pop.sample(n=5).sample(n=5, axis=1).plot.bar()

# %%
df_pop.sample(n=5).sample(n=5, axis=1).plot.bar(stacked=True)

# %%
df_lifeExp.sample(n=5).sample(n=2, axis=1).plot.pie(subplots=True, figsize=(10, 5), legend=False)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000020D798D4C50>,
# ...
#       dtype=object)

# %% [markdown]
# # Resources

# %% [markdown]
# These ideas came mostly from the pandas visualization here:
# https://pandas.pydata.org/pandas-docs/stable/visualization.html
